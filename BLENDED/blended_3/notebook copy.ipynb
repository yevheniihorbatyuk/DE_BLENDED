# %%
from kafka.admin import KafkaAdminClient, NewTopic
from configs import kafka_config

# %%
# Load Kafka configuration
bootstrap_servers = kafka_config.get('bootstrap_servers')
security_protocol = kafka_config.get('security_protocol', 'PLAINTEXT')
sasl_mechanism = kafka_config.get('sasl_mechanism', 'PLAIN')
sasl_plain_username = kafka_config.get('username', '')
sasl_plain_password = kafka_config.get('password', '')

# Create Kafka Admin Client
admin_client = KafkaAdminClient(
    bootstrap_servers=bootstrap_servers,
    security_protocol=security_protocol,
    sasl_mechanism=sasl_mechanism,
    sasl_plain_username=sasl_plain_username,
    sasl_plain_password=sasl_plain_password
)

# %%
# Kafka topics to check
topics_to_check = ['topic_ilya_in-1', 'topic_ilya_in-0']

# %%
# Fetch the list of existing topics
existing_topics = admin_client.list_topics()
existing_topics
# Out:
# ['kilaru_enriched_athlete_avg',
#  'yuliia_iot_sensors_data',
#  'ginger_athlete_event_results',
#  'AS_temperature_alerts',
#  'oleg_building_sensors',
#  'humidity_alerts_volodymyr14',
#  'kari_morozova_building_sensors',
#  'kry_temperature_alerts',
#  'kaplan_m_temperature_alerts',
#  'kari_shop_topic_1',
#  'churylov_yevhen_0107_athlete_event_results',
#  'Vitalii_topic_1',
#  'iot_alerts',
#  'common_alerts_msolonin',
#  'output_SerhiiB',
#  'building_sensors_serafymovych',
#  'kry_spark_streaming_in',
#  'ilya_topic_out_1',
#  'sergii_humidity_alerts',
#  'temperature_alerts_romanchuk',
#  'building_sensors_eod_goit_de_hw_06',
#  'iot_sensors_data',
#  'temperature_alerts_eugene_churylov_1',
#  'yuliia_iot_alerts',
#  'yuliia_nazymko_athlete_avg_stats',
#  'lesia999_humidity_alerts',
#  'oleksiy58_topic_1',
#  'humidity_alerts_msolonin',
#  'humidity_alerts_oleh3',
#  'humidity_alerts_my_unique_id',
#  'humidity_alerts_oholodetskyi',
#  'AS_building_sensors',
#  'test',
#  'avg_bio_results',
#  'ilya_humidity_alerts',
#  'YT_building_sensors',
#  'humidity_alerts_volodymyr8',
#  'humidity_alerts_eugene_churylov_1',
#  'eod_athlete_enriched',
#  'viktori_humidity_alerts',
#  'YT_athlete_event_results',
#  'akolvakh_sensor_alerts',
#  'building_sensors_volodymyr15',
#  'AS_topic_out',
#  'ilya_topic_in_1',
#  'ginger_athlete_enriched_avg',
#  'building_sensors_buhai',
#  'temperature_alerts_oleh47',
#  'temperature_alerts_my_unique_id',
#  'oleksandra-topic-2',
#  'zheyadatsenko_humidity_alerts',
#  'gregory_building_sensors',
#  'building_sensors_oholodetskyi',
#  'viktori_building_sensors',
#  'sensor_alerts',
#  'topic_BTCUSDT',
#  'building_sensors_volodymyr12',
#  'oleksiy_iot_sensors_data',
#  'humidity_alerts_volodymyr3',
#  'lesia_soloviova_topic_enriched_athlete_avg',
#  'ilya_building_sensor_1',
#  'pipa_enriched_athlete_avg',
#  'Serafymovych_topic_1',
#  'veronika2_topic_1',
#  'temperature_alerts_volodymyr1',
#  'oleksiy_topic_1',
#  'building_sensors_volodymyr16',
#  'zhenya_datsenko_athlete_avg_stats',
#  'RomanS_building_sensors',
#  'andriy_b_humidity_alerts',
#  'kilaru_athlete_event_results',
#  'lesiaukr_humidity_alerts',
#  'athletes_msolonin',
#  'ivan_alerts',
#  'padma_humidity_alerts',
#  'oleksiy123_topic_1',
#  'edwardprom_humidity_alerts',
#  'building_sensors_alerts_MZ',
#  'oleksiy57_topic_1',
#  'rudyi_athlete_results',
#  'akolvakh_building_sensors',
#  'temperature_alerts_green',
#  'kry_building_sensors',
#  'lina_building_sensors',
#  'AS_athlete_event_results',
#  'kaplan_i_humidity_alerts',
#  'vvd_temperature_alerts',
#  'my_new_topic',
#  'artur_temperature_alerts',
#  'karine_humidity_alerts',
#  'kari_topic_1',
#  'building_sensors_your_name',
#  'Seraf_building_sensors',
#  'karine_morozova_building_sensors',
#  'oleksandratk_temperature_alerts',
#  'humidity_alerts_your_unique_username',
#  'iuliia_alerts',
#  'andrew_motko_athlete_event_results',
#  'lesia123_building_sensors',
#  'viktoriia_humidity_alerts',
#  'alina_ryabova_enriched_athlete_avg',
#  'AS_FP_part1_out',
#  'humidity_alerts_Serafymoovych',
#  'lina_alerts',
#  'building_sensors_DESKTOP-L5OQROE',
#  'building_sensors_msolonin',
#  'YT_temperature_alerts',
#  'YT_humidity_alerts',
#  'building_sensors_Serafymovych',
#  'andriy_b_building_sensors',
#  'kristina_topic_1',
#  'pepe_enriched_athlete_avg',
#  'kaplan_i_building_sensors',
#  'lesia_building_sensors',
#  'lesia999_building_sensors',
#  'building_sensors_volodymyr3',
#  'humidity_alerts_volodymyr17',
#  'IOT_iot_sensors_data',
#  'edwardprom_temperature_alerts',
#  'zhenya_datsenko_athlete_event_results',
#  'kro_enriched_athlete_avg',
#  'humidity_alerts_romanchuk',
#  'kro_athlete_event_results',
#  'sergiik_building_sensors_in',
#  'oleksandratk_humidity_alerts',
#  'my_topic_1',
#  'oholodetskyi_humidity_alerts',
#  'building_sensors_oleksiy',
#  'lesia_iot_sensors_aggregated',
#  'IOT_building_sensors',
#  'vvd_building_sensors_alerts',
#  'karine_morozova_temperature_alerts',
#  'building_sensors_oleh3',
#  'Artur_enriched_athlete_avg',
#  'temperature_alerts_volodymyr9',
#  'zhenyadatsenko_iot_alerts',
#  'ilya_topic_in',
#  'vika_humidity_alerts',
#  'athlete_event_results_iuliia_enriched',
#  'eduard_topic_1',
#  'temperature_alerts_volodymyr4',
#  'avg_alerts_buhai',
#  'building_sensors_volodymyr4',
#  'humidity_alerts_volodymyr2',
#  'akolvakh_athlete_event_results',
#  'athlete_event_results_iuliia',
#  'biba_humidity_alerts',
#  'vika_building_sensors',
#  'serafymovych_spark_streaming_out',
#  'VN_temperature_alerts',
#  'churylov_yevhen_0107_enriched_athlete_avg',
#  'humidity_alerts_Serafymovych',
#  'athlete_event_results_MZh',
#  'k_temperature_alerts',
#  'oleksandratk_athlete_event_results',
#  'athlete_event_results_iuliia_2',
#  'aggregated_sensors_your_unique_username',
#  'ilya_topic_out',
#  'oleh_aggregated_athlete_stats',
#  'athletes_KostyaM',
#  'akukla_enriched_athlete_avg',
#  'building_sensors',
#  'humidity_alerts_volodymyr13',
#  'vika_athlete_event_results_input',
#  'iuliia_all_alerts',
#  'gree_topic_1',
#  'creating_sensors',
#  'humidity_alerts_topic',
#  'karine_morozova_humidity_alerts',
#  'ovova1_topic_1',
#  'Ivan_Yanchyk_topic_1',
#  'eugene_topic_1',
#  'viktoriia_temperature_alerts',
#  'building_sensors_volodymyr1',
#  'building_sensors_volodymyr',
#  'temperature_alerts_volodymyr10',
#  'lesia999_iot_alerts',
#  'Alina_iot_sensors_data',
#  'zhenyadatsenko_iot_sensors_data',
#  'artur_home_building_sensors_in',
#  'oleksiy_iot_alerts',
#  'alerts_condition_oleksandr_topic',
#  'humidity_alerts_MZ',
#  'viktori_temperature_alerts',
#  'akolvakh_enriched_athlete_avg',
#  'lina_aggregated_athlete_stats',
#  'kaplan_m_building_sensors',
#  'kar_humidity_alerts',
#  'Eduard_topic_1',
#  'kari_morozova_humidity_alerts',
#  'oholodetskyi_building_sensors',
#  'building_sensors_greenmoon',
#  'temperature_alerts_volodymyr8',
#  'temperature_alerts_vchub',
#  'k_building_sensors',
#  'building_sensors_volodymyr9',
#  'humidity_alerts_eugene_churylov',
#  'building_sensors_eugene',
#  'YT_aggregated_athlete_stats',
#  'temperature_alerts_rudyi',
#  'viktorii_building_sensors',
#  'humidity_alerts_eugene',
#  'padma_building_sensors',
#  'oleksiy7_topic_1',
#  'building_sensors_spogoretskyi',
#  'building_sensors_churylov_eugene_1',
#  'temperature_alerts_volodymyr14',
#  'oleksandratk_kafka_alerts',
#  'building_sensors_yevhenii_mentor',
#  'oleksiy56_topic_1',
#  'humidity_alerts_nesvit',
#  'Iana_topic_1',
#  'kafka_temperature_alerts',
#  'temperature_alerts_your_unique_username',
#  'temperature_alerts_volodymyr17',
#  'oleksandra-topic-1',
#  'kafka_humidity_alerts',
#  'kar_building_sensors',
#  'avg_alerts',
#  'humidity_alerts_volodymyr10',
#  'sensors_notifier',
#  'artur_home_building_sensors_out',
#  'temperature_alerts_goit_goit_de_hw_05',
#  'vvd_humidity_alerts',
#  'zhenya_datsenko_iot_alerts',
#  'alina_ryabova_athlete_event_results',
#  'biba_temperature_alerts',
#  'building_sensors_MZ',
#  'lesia999_temperature_alerts',
#  'humidity_alerts_oleh47',
#  'lina_temperature_alerts',
#  'kaplan_m_humidity_alerts',
#  'out_topic_name',
#  'viktoriia_streaming_building_sensors',
#  'artur_home_enriched_athlete_avg',
#  'yuliia_nazymko_athlete_event_results',
#  'building_sensors_your_unique_username',
#  '__consumer_offsets',
#  'AS_humidity_alerts',
#  'KostyaM_building_sensors',
#  'Artur_athlete_event_results',
#  'Artur_athlete_enriched_agg',
#  'zheyadatsenko_building_sensors',
#  'humidity_alerts_spogoretskyi',
#  'alerts_rudyi',
#  'tati_iot_alerts',
#  'veronika_topic_1',
#  'lina_athlete_event_results',
#  'shop_123',
#  'kry_humidity_alerts',
#  'greenmoon__topic_1',
#  'lesia999_alerts',
#  'Serafymovych_streaming_out',
#  'kaplan_i_temperature_alerts',
#  'lina_humidity_alerts',
#  'temperature_alerts_volodymyr11',
#  'temperature_alerts_volodymyr3',
#  'vika_temperature_alerts',
#  'building_sensors_volodymyr8',
#  'YT_spark_streaming_out',
#  'lesia_topic_1',
#  'humidity_alerts_oleksiy',
#  'edwardprom_building_sensors',
#  'building_sensors_goit_goit_de_hw_05',
#  'kariMo_alert_topic',
#  'ilya_alerts_topic',
#  'building_sensors_volodymyr13',
#  'VN_humidity_alerts',
#  'viktorii_humidity_alerts',
#  'akolvakh_temperature_alerts',
#  'all_data_out_MZh',
#  'lesia_soloviova_athlete_event_results',
#  'temperature_alerts_msolonin',
#  'artur_home_building_sensors',
#  'viktorii_temperature_alerts',
#  'temperature_alerts_Serafymoovych',
#  'humidity_alerts_volodymyr12',
#  'lina_spark_streaming_out',
#  'humidity_alerts_oleh',
#  'building_sensors_topic',
#  'padma_topic_1',
#  'humidity_alerts_volodymyr',
#  'artur_home_athlete_event_results',
#  'padma_temperature_alerts',
#  'output_topic',
#  'oleksiy55_topic_1',
#  'sergiik_building_alerts',
#  'andriy_b_topic_1',
#  'temperature_alerts_oleksandr_topic',
#  'temperature_alerts_Serafymovych',
#  'temperature_alerts_eugene_churylov',
#  'oleksiy_spark_streaming_in',
#  'morozova_building_sensors',
#  'lesia_soloviova_enriched_athlete_avg',
#  'iuliia_building_sensors_alerts',
#  'kari_building_sensors',
#  'kari_morozova_temperature_alerts',
#  'greenmoon_end_enriched_athlete_avg',
#  'humidity_alerts_oleksandr_topic',
#  'iuliia_building_alerts',
#  'topic_ETHUSDT',
#  'akukla_athlete_event_results',
#  'lesia999_iot_sensors_data',
#  'ivan_sensors_data',
#  'andriy_b_temperature_alert',
#  'rudyi_athlete_event_results',
#  'temperature_alerts',
#  'VN_building_sensors',
#  'building_sensors_Buhai',
#  'temperature_alerts_volodymyr12',
#  'oholodetskyi_temperature_alerts',
#  'building_sensors_churylov_eugene_2',
#  'building_sensors_oleksandr_topic',
#  'viktoriia_streaming_alerts',
#  'Serafymovych_topic_2',
#  'spogoretskyi_enriched_athlete_avg',
#  'jane_topic_1',
#  'lina_spark_streaming_in',
#  'yuliia_temperature_alerts',
#  'temperature_alerts_oleh',
#  'alert_Kafka_topic_churylov_eugene_2',
#  'alerts_eod_goit_de_hw_06',
#  'gregory_temperature_alerts',
#  'churylov_enriched_athlete_avg',
#  'vchub_athlete_aggregated',
#  'alert_Kafka_topic_churylov_eugene',
#  'building_sensors_oleh',
#  'greenmoon_end_athlete_event_results',
#  'lesia_humidity_alerts',
#  'morozova_humidity_alerts',
#  'Serafymovych_building_sensors',
#  'temperature_alerts_oleh3',
#  'oleksiy_spark_streaming_out',
#  'humidity_alerts_volodymyr16',
#  'andriy_b_temperature_alerts',
#  'biba_building_sensors',
#  'your_name_temperature_alerts',
#  'AS_topic_in',
#  'building_sensors_volodymyr10',
#  'lesia_iot_alerts',
#  'humidity_alerts_green',
#  'humidity_alerts',
#  'temperature_alerts_volodymyr13',
#  'humidity_alerts_vchub',
#  'sergiik_building_sensors_out',
#  'building_sensors_oleh47',
#  'artur_humidity_alerts',
#  'oleg_alerts',
#  'topic_ilya_in',
#  'output_msolonin',
#  'your_name_humidity_alerts',
#  'lesia_temperature_alerts',
#  'iuliia_temperature_alerts',
#  'building_sensors_churylov_eugene',
#  'oleksandratk_building_sensors',
#  'lesia123_temperature_alerts',
#  'karine_temperature_alerts',
#  'humidity_alerts_goit_goit_de_hw_05',
#  'temperature_alerts_greenmoon',
#  'oleh_athlete_event_results',
#  'kar_temperature_alerts',
#  'humidity_alerts_greenmoon',
#  'building_sensors_eugene_churylov_1',
#  'oleksiy67_topic_1',
#  'aggregated_results',
#  'andriy_b_humidity_alert',
#  'temperature_alerts_topic',
#  'temperature_alerts_oholodetskyi',
#  'ilya_topic_1',
#  'lesia_topic_enriched_athlete_avg',
#  'test_topic',
#  'temperature_alerts_volodymyr',
#  'RomanS_alert_Kafka_topic',
#  'sergiik_building_sensors',
#  'andrew_motko_enriched_athlete_avg',
#  'humidity_alerts_volodymyr9',
#  'temperature_alerts_MZ',
#  'veronika4_topic_1',
#  'ilya_temperature_alerts',
#  'humidity_alerts_DESKTOP-L5OQROE',
#  'sergii_temperature_alerts',
#  'yuliia_building_sensors',
#  'veronika1_topic_1',
#  'humidity_alerts_volodymyr11',
#  'temperature_alerts_DESKTOP-L5OQROE',
#  'temperature_alerts_volodymyr2',
#  'temperature_alerts_volodymyr16',
#  'athletes_SerhiiB',
#  'avg_alerts_romanchuk',
#  'lesia123_humidity_alerts',
#  'humidity_alerts_volodymyr4',
#  'IOT_humidity_alerts',
#  'temperature_alerts_volodymyr15',
#  'vvd_building_sensors',
#  'lesia_soloviova_topic_athlete_event_results',
#  'Alina_iot_alerts',
#  'viktoriia_building_sensors',
#  'morozova_temperature_alerts',
#  'kaplan_m_athlete_enriched_agg',
#  'IOT_temperature_alerts',
#  'sergii_building_sensors',
#  'kry_streaming_out',
#  'your_name_building_sensors',
#  'Yana_topic_1',
#  'Alex_topic_1',
#  'k_humidity_alerts',
#  'building_sensors_volodymyr17',
#  'alerts_your_unique_username',
#  'artur_topic_1',
#  'event_results_YM',
#  'building_sensors_nesvit',
#  'building_sensors_rudyi',
#  'vchub_athlete_event_results',
#  'karine_building_sensors',
#  'output_KostyaM',
#  'building_sensors_eugene_churylov',
#  'lesiaukr_temperature_alerts',
#  'yuliia_humidity_alerts',
#  'kafka_out_vvd',
#  'vika_athlete_event_results_output',
#  'topic_FTMUSDT',
#  'pipa_athlete_event_results',
#  'churylov_athlete_event_results',
#  'athlete_event_results_ivan_y',
#  'building_sensors_volodymyr2',
#  'currency_raw_dat',
#  'lesia_iot_sensors_data',
#  'humidity_alerts_volodymyr1',
#  'IOT_iot_alerts',
#  'building_sensors_vchub',
#  'lesiaukr_building_sensors',
#  'kaplan_m_test',
#  'kari_temperature_alerts',
#  'kariMo_building_sensors',
#  'humidity_alerts_rudyi',
#  'lina_topic_1',
#  'temperature_alerts_nesvit',
#  'building_sensors_volodymyr11',
#  'iuliia_building_sensors',
#  'athlete_enriched_agg',
#  'topic_XRPUSDT',
#  'building_sensors_volodymyr14',
#  'topic_athlete_event_results',
#  'KostyaM_alert_Kafka_topic',
#  'viktor_svertoka_athlete_event_results',
#  'currency_raw_data',
#  'zhenya_datsenko_iot_sensors_data',
#  'alert_Kafka_topic_churylov_eugene_1',
#  'viktor_svertoka_enriched_athlete_avg',
#  'temperature_alerts_spogoretskyi',
#  'greenmoon_topic_1',
#  'alert_Kafka_topic',
#  'iuliia_humidity_alerts',
#  'avg_results_YM',
#  'aggregated_results_ivan_y',
#  'veronika3_topic_1',
#  'kari_humidity_alerts',
#  'gregory_humidity_alerts',
#  'tati_iot_sensors_data',
#  'gregory_topic_1',
#  'vchub_athlete_aggreted',
#  'building_sensors_my_unique_id',
#  'lesia_topic_athlete_event_results',
#  'akolvakh_humidity_alerts',
#  'zheyadatsenko_temperature_alerts',
#  'oleksandratk_athlete_enriched',
#  'pepe_athlete_event_results',
#  'athlete_event_results',
#  'building_sensors_romanchuk',
#  'kafka_building_sensors',
#  'kaplan_m_athlete_event_results',
#  'alert_Kafka_topic_churyov_eugene_2',
#  'temperature_alerts_oleksiy',
#  'humidity_alerts_volodymyr15']

# %%
# Check if topics exist and create if missing
missing_topics = [topic for topic in topics_to_check if topic not in existing_topics]

if not missing_topics:
    print("All topics exist:", topics_to_check)
else:
    print("The following topics are missing and will be created:", missing_topics)
    new_topics = [NewTopic(name=topic, num_partitions=1, replication_factor=1) for topic in missing_topics]
    try:
        admin_client.create_topics(new_topics=new_topics, validate_only=False)
        print("Missing topics created successfully.")
    except Exception as e:
        print(f"An error occurred while creating topics: {e}")
# Out:
# The following topics are missing and will be created: ['topic_ilya_in-1', 'topic_ilya_in-0']
# Missing topics created successfully.

# %%
# remove topics
admin_client.delete_topics(['topic_ilya_in-1', 'topic_ilya_in-0'])
# Out:
# DeleteTopicsResponse_v3(throttle_time_ms=0, topic_error_codes=[(topic='topic_ilya_in-1', error_code=0), (topic='topic_ilya_in-0', error_code=0)])

# %%
# Close the admin client connection
admin_client.close()
